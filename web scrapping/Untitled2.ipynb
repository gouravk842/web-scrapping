# %%
from imagescanner import ImageScanner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4184608887b7> in <module>
# ----> 1 from imagescanner import ImageScanner
#
# ModuleNotFoundError: No module named 'imagescanner'

# %%
from imagescanner import ImageScanner

 # instantiate the imagescanner obj 
iscanner = ImageScanner()

 # get all available devices
scanners = iscanner.list_scanners()

 # choose one of the devices
scanner = scanners[0]

 # scan your file (returns a PIL object)
scanner.scan()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b8111d3af3b3> in <module>
# ----> 1 from imagescanner import ImageScanner
#       2
#       3  # instantiate the imagescanner obj
#       4 iscanner = ImageScanner()
#       5
#
# ModuleNotFoundError: No module named 'imagescanner'
